# %% [markdown]
# # 10. Predicates
# #### By Kwan Yin Andrew Chau

# %%
import nbfinder
from loader import g
from loader import P
from loader import __
from loader import hkVertexId
from loader import sydneyVertexId

# %% [markdown]
# ## eq()
# __Airports that have 5 runways__

# %%
g.V().has('runways', P.eq(5)).values('desc').fold().next()
# Out:
# ['Paraparaumu Airport',
#  'Tauranga Airport',
#  'Toronto Pearson International Airport',
#  'Hamilton International Airport',
#  'Shannon Airport',
#  'George Bush Intercontinental',
#  'Hartsfield - Jackson Atlanta International Airport',
#  'Ufa International Airport',
#  'Napier Airport',
#  'General Mitchell International Airport',
#  'Gisborne Airport',
#  'Karup Airport',
#  'Chicago Midway International Airport',
#  'Nelson Airport']

# %% [markdown]
# ## neq()
# __Airports that do not have 4 runways__

# %%
x1 = g.V().has('runways', P.neq(4)).count().next()
g.V().has('runways', P.neq(4)).values('desc').fold().next()
# Out:
# ['Verona Villafranca Airport',
#  'Pico Airport',
#  'East Texas Regional Airport',
#  'Gothenburg City Airport',
#  'Raleigh-Durham',
#  'Tbilisi International Airport',
#  'Rarotonga International Airport',
#  'Bhutan',
#  'Aurangabad Airport',
#  'Lipetsk Airport',
#  'Vnukovo International Airport',
#  'Robert (Bob) Curtis Memorial Airport',
#  'Gyumri Shirak Airport',
#  'Aksu Airport',
#  'Lima, Jorge Chavez International Airport',
#  'Dawei Airport',
#  'Luxor International Airport',
#  'Ranong Airport',
#  'General Ignacio P. Garcia International Airport',
#  'Rock Sound Airport',
#  'Alexander the Great International Airport',
#  'El Plumerillo Airport',
#  'Raiatea Airport',
#  'Owensboro Daviess County Airport',
#  'Ulan-Ude Airport (Mukhino)',
#  'Syracuse Hancock International Airport',
#  'Lokichoggio Airport',
#  'Jessore Airport',
#  'Show Low Regional Airport',
#  'Mauritania',
#  'Fort Nelson Airport',
#  'Republic of Korea',
#  'Providenciales Airport',
# ...

# %% [markdown]
# ## not()
# __Can also achieve the same thing__

# %%
x2 = g.V().not_(__.values('runways').is_(4)).count().next()
assert x1 == x2

# %% [markdown]
# ## and()
# __To add another condition__

# %%
g.V().and_(__.has('runways', P.neq(4)), __.has('runways', P.neq(3))).valueMap('code', 'runways').fold().next()
# Out:
# [{'runways': [1], 'code': ['VRN']},
#  {'runways': [1], 'code': ['PIX']},
#  {'runways': [2], 'code': ['GGG']},
#  {'runways': [2], 'code': ['GSE']},
#  {'runways': [2], 'code': ['TBS']},
#  {'runways': [1], 'code': ['RAR']},
#  {'code': ['BT']},
#  {'runways': [1], 'code': ['IXU']},
#  {'runways': [1], 'code': ['LPK']},
#  {'runways': [2], 'code': ['VKO']},
#  {'runways': [1], 'code': ['ORV']},
#  {'runways': [1], 'code': ['LWN']},
#  {'runways': [1], 'code': ['AKU']},
#  {'runways': [1], 'code': ['LIM']},
#  {'runways': [1], 'code': ['TVY']},
#  {'runways': [1], 'code': ['LXR']},
#  {'runways': [1], 'code': ['UNN']},
#  {'runways': [2], 'code': ['HMO']},
#  {'runways': [1], 'code': ['RSD']},
#  {'runways': [1], 'code': ['KVA']},
#  {'runways': [1], 'code': ['MDZ']},
#  {'runways': [1], 'code': ['RFP']},
#  {'runways': [2], 'code': ['OWB']},
#  {'runways': [1], 'code': ['LKG']},
#  {'runways': [1], 'code': ['JSR']},
#  {'runways': [2], 'code': ['SOW']},
#  {'code': ['MR']},
# ...

# %% [markdown]
# ## gt()
# __Airports that have more than 5 runways__

# %%
x1 = g.V().has('runways', P.gt(5)).count().next()
x1
# Out:
# 6

# %% [markdown]
# ## gte()
# __Airports that have 6 or more runways__

# %%
x2 = g.V().has('runways', P.gte(6)).count().next()
assert x1 == x2

# %% [markdown]
# ## lt()
# __Airports that have less than 3 runways__

# %%
x1 = g.V().has('runways', P.lt(3)).count().next()
x1
# Out:
# 3078

# %% [markdown]
# ## lte()
# __Airports that have 2 or less runways__

# %%
x2 = g.V().has('runways', P.lte(2)).count().next()
assert x1 == x2

# %% [markdown]
# ## inside()
# __Airports that have more than 2 but less than 6 runways__
#
# _There is an issue with this Python implementation of inside, 2 should not be inclusive_

# %%
 g.V().has('runways', P.inside(2, 6)).valueMap('code', 'runways').fold().next()
# Out:
# [{'runways': [4], 'code': ['KKE']},
#  {'runways': [2], 'code': ['GGG']},
#  {'runways': [2], 'code': ['GSE']},
#  {'runways': [3], 'code': ['RDU']},
#  {'runways': [2], 'code': ['TBS']},
#  {'runways': [2], 'code': ['VKO']},
#  {'runways': [2], 'code': ['HMO']},
#  {'runways': [2], 'code': ['OWB']},
#  {'runways': [3], 'code': ['UUD']},
#  {'runways': [3], 'code': ['SYR']},
#  {'runways': [2], 'code': ['SOW']},
#  {'runways': [3], 'code': ['YYE']},
#  {'runways': [2], 'code': ['WAW']},
#  {'runways': [2], 'code': ['SVO']},
#  {'runways': [2], 'code': ['SBP']},
#  {'runways': [3], 'code': ['DME']},
#  {'runways': [2], 'code': ['CZM']},
#  {'runways': [2], 'code': ['FMN']},
#  {'runways': [2], 'code': ['KSD']},
#  {'runways': [2], 'code': ['ABY']},
#  {'runways': [2], 'code': ['MUC']},
#  {'runways': [2], 'code': ['PMO']},
#  {'runways': [4], 'code': ['FRA']},
#  {'runways': [2], 'code': ['LIL']},
#  {'runways': [4], 'code': ['TMW']},
#  {'runways': [2], 'code': ['ERI']},
# ...

# %%
x1 = g.V().has('runways', P.inside(2, 6)).count().next()
x1
# Out:
# 1052

# %% [markdown]
# ## outside()
# __Airports that have less than 3 or more than 5 runways__

# %%
y1 = g.V().has('airport', 'runways', P.outside(3, 5)).count().next()
y1
# Out:
# 3084

# %% [markdown]
# ## within()
# __Airports that have 3 or more but 5 or less runways__

# %%
# x3 = g.V().has('runways', P.within(3..5)).count().next()
# assert x1 == x3

# %% [markdown]
# __Airports with 3, 4 or 5 runways__

# %%
x4 = g.V().has('runways', P.within([3,4,5])).count().next()
# assert x3 == x4
x4
# Out:
# 290

# %% [markdown]
# ## without()
# __Airports that have less than 3 or more than 5 runways__

# %%
# x5 = g.V().has('runways', P.without(3..5)).count().next()
# assert x2 == x5

# %% [markdown]
# __Airports that do not have 3, 4 or 5 runways__

# %%
y2 = g.V().has('airport', 'runways', P.without([3,4,5])).count().next()
assert y1 == y2

# %% [markdown]
# ## between()
# __Airports that have 3 or more but less than 6 runways__

# %%
x6 = g.V().has('runways', P.between(3, 6)).count().next()
assert x4 == x6

# %% [markdown]
# __Has vertex ID within Sydney's and Hong Kong's__

# %%
g.V().hasId(P.within([sydneyVertexId, hkVertexId])).values('code').fold().next()
# Out:
# ['HKG', 'SYD']

# %% [markdown]
# __Airports in NSW that do not have the city "Sydney"__

# %%
g.V().has('airport','region','AU-NSW').has('city', P.neq('Sydney')).values('city').fold().next()
# Out:
# ['Tamworth',
#  'Port Macquarie',
#  'Lismore',
#  'Wagga Wagga',
#  'Moruya',
#  'Albury',
#  'Taree',
#  'Merimbula',
#  'Parkes',
#  'Coffs Harbour',
#  'Narrandera',
#  'Griffith',
#  'Narrabri',
#  'Lord Howe Island',
#  'Bathurst',
#  'Orange',
#  'Gold Coast',
#  'Grafton',
#  'Ballina',
#  'Williamtown',
#  'Moree',
#  'Broken Hill',
#  'Dubbo',
#  'Armidale']

# %% [markdown]
# __Path of flights from Hong Kong to Sydney which have 1 stop in Australia__

# %%
g.V().has('airport','code','HKG').out().has('country', P.within('AU')).out().has('code','SYD').path().by('code').fold().next()
# Out:
# [['HKG', 'BNE', 'SYD'],
#  ['HKG', 'MEL', 'SYD'],
#  ['HKG', 'CNS', 'SYD'],
#  ['HKG', 'PER', 'SYD'],
#  ['HKG', 'ADL', 'SYD']]

# %% [markdown]
# __Path of flights from Hong Kong to Sydney which do not have 1 stop in Australia, Japan or China__

# %%
g.V().has('airport','code','HKG').out().has('country', P.without(['AU', 'JP', 'CN'])).out().has('code','SYD').path().by('country').fold().next()
# Out:
# [['HK', 'US', 'AU'],
#  ['HK', 'US', 'AU'],
#  ['HK', 'US', 'AU'],
#  ['HK', 'QA', 'AU'],
#  ['HK', 'NZ', 'AU'],
#  ['HK', 'TH', 'AU'],
#  ['HK', 'MY', 'AU'],
#  ['HK', 'VN', 'AU'],
#  ['HK', 'ID', 'AU'],
#  ['HK', 'KR', 'AU'],
#  ['HK', 'ZA', 'AU'],
#  ['HK', 'ID', 'AU'],
#  ['HK', 'CA', 'AU'],
#  ['HK', 'AE', 'AU'],
#  ['HK', 'SG', 'AU'],
#  ['HK', 'AE', 'AU'],
#  ['HK', 'IN', 'AU'],
#  ['HK', 'PH', 'AU'],
#  ['HK', 'PG', 'AU'],
#  ['HK', 'TH', 'AU'],
#  ['HK', 'VN', 'AU'],
#  ['HK', 'FJ', 'AU'],
#  ['HK', 'TW', 'AU']]

# %% [markdown]
# __Between can also be used to simulate "starts with"__
#
# All airports that have a city name starting with "Dal" or "Dam"

# %%
g.V().has('city', P.between('Dal', 'Dam')).values('city').dedup().fold().next()
# Out:
# ['Dalcahue', 'Dalat', 'Dalanzadgad', 'Dalaman', 'Dalian', 'Dallas']

# %% [markdown]
# __Trick to find strings that begin with a single character (S)__

# %%
g.V().has('airport','code',P.between('S','Sa')).values('code').fold().next()
# Out:
# ['SYR',
#  'SOW',
#  'SVO',
#  'SBP',
#  'SGF',
#  'SVJ',
#  'SJL',
#  'SDJ',
#  'SSR',
#  'SPN',
#  'SIT',
#  'SJP',
#  'SJZ',
#  'SDL',
#  'SRP',
#  'SLC',
#  'SLY',
#  'SOG',
#  'SFG',
#  'SJE',
#  'SBN',
#  'SRG',
#  'SNN',
#  'SYY',
#  'SHV',
#  'SEA',
#  'SCN',
#  'SCC',
#  'SGC',
#  'SKG',
#  'SDQ',
#  'SGN',
#  'SHW',
#  'SAL',
#  'SVP',
#  'SVK',
#  'SHR',
#  'SCV',
#  'SGO',
#  'SYX',
#  'SJC',
#  'SGU',
#  'SNE',
#  'SOU',
#  'SYM',
#  'STS',
#  'SVA',
#  'SYO',
#  'SUF',
#  'SFJ',
#  'SZX',
#  'SKO',
#  'STI',
#  'SFO',
#  'SDR',
#  'SZI',
#  'SDU',
#  'SCW',
#  'SCT',
#  'SNW',
#  'SMF',
#  'SHM',
#  'SPD',
#  'SYD',
#  'SFL',
#  'SAW',
#  'SIN',
#  'SOQ',
#  'SVD',
#  'SHD',
#  'SXP',
#  'SAV',
#  'SZF',
#  'SZB',
#  'SKZ',
#  'SHC',
#  'SOY',
#  'SUV',
#  'SHF',
#  'SVL',
#  'SMX',
#  'SZA',
#  'STC',
#  'SUB',
#  'SVU',
#  'SZG',
#  'SHA',
#  'SOM',
#  'SCL',
#  'SRQ',
#  'SFN',
#  'SLQ',
#  'SON',
#  'SMK',
#  'SSY',
#  'SWA',
#  'SMS',
#  'SDF',
#  'SAN',
#  'SNO',
# ...
